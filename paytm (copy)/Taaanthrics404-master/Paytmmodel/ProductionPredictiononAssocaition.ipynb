# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv('/home/manthan/Desktop/paytm/Taaanthrics404-master/Paytmmodel/crowddatasetforsihmodified.csv')

# %%
dataset
# Out:
#      Unnamed: 0  Age               Catagory             Color        Date  \
# 0             0   39      ComputerAndMobile            Violet  2015-02-24
# 1             1   53                Fashion         DarkGreen  2015-06-07
# 2             2   53                Fashion            Bisque  2015-01-01
# 3             3   41      ComputerAndMobile       SaddleBrown  2015-04-28
# 4             4   45             Grossaries  MediumAquaMarine  2015-07-21
# 5             5   18                Fashion       FloralWhite  2015-05-21
# 6             6   19      ComputerAndMobile     DarkSlateBlue  2015-08-01
# 7             7   34             Grossaries              Aqua  2015-04-06
# 8             8   43      ComputerAndMobile            Salmon  2015-04-21
# 9             9   31      ComputerAndMobile             Brown  2015-01-25
# 10           10   35      ComputerAndMobile            Tomato  2015-07-11
# 11           11   32      ComputerAndMobile            Tomato  2015-05-29
# 12           12   33      ComputerAndMobile         RoyalBlue  2015-06-16
# 13           13   38      ComputerAndMobile            Bisque  2015-03-03
# 14           14   24                Fashion          DarkBlue  2015-02-16
# 15           15   24                Fashion              Peru  2015-02-01
# 16           16   23                Fashion        PowderBlue  2015-05-15
# 17           17   38             Grossaries         OliveDrab  2015-03-20
# 18           18   24                Fashion              Cyan  2015-02-03
# 19           19   53             Grossaries     LightSeaGreen  2015-07-17
# 20           20   23      ComputerAndMobile         PeachPuff  2015-07-08
# 21           21   28      ComputerAndMobile             Black  2015-08-08
# 22           22   24      ComputerAndMobile             Olive  2015-01-30
# 23           23   34  ElectronicsAppliances            Silver  2015-01-08
# 24           24   35             Grossaries             Wheat  2015-01-11
# 25           25   36      ComputerAndMobile              Teal  2015-01-04
# 26           26   32  ElectronicsAppliances             Linen  2015-01-28
# 27           27   28  ElectronicsAppliances   MediumSlateBlue  2015-07-12
# 28           28   19      ComputerAndMobile      LemonChiffon  2015-05-29
# 29           29   27             Grossaries        DarkOrchid  2015-01-07
# ..          ...  ...                    ...               ...         ...
# 470         470   21      ComputerAndMobile         SlateGray  2015-08-14
# 471         471   33             Grossaries            Bisque  2015-01-12
# 472         472   41             Grossaries            Orange  2015-06-27
# 473         473   39      ComputerAndMobile           DimGray  2015-06-07
# 474         474   36      ComputerAndMobile        MediumBlue  2015-02-13
# 475         475   26      ComputerAndMobile      AntiqueWhite  2015-06-02
# 476         476   42             Grossaries             Beige  2015-02-08
# 477         477   26             Grossaries             Beige  2015-05-26
# 478         478   23      ComputerAndMobile         PeachPuff  2015-02-14
# 479         479   35  ElectronicsAppliances         LightPink  2015-01-15
# 480         480   32      ComputerAndMobile        WhiteSmoke  2015-07-08
# 481         481   31             Grossaries      MediumOrchid  2015-05-15
# 482         482   43      ComputerAndMobile             Olive  2015-05-15
# 483         483   41             Grossaries         MistyRose  2015-07-02
# 484         484   33  ElectronicsAppliances           DarkRed  2015-05-08
# 485         485   37  ElectronicsAppliances              Pink  2015-04-28
# 486         486   47             Grossaries          DarkGray  2015-04-06
# 487         487   37             Grossaries            Orchid  2015-06-12
# 488         488   29             Grossaries         PeachPuff  2015-04-05
# 489         489   33             Grossaries           Magenta  2015-01-21
# 490         490   28      ComputerAndMobile        GhostWhite  2015-01-11
# 491         491   25                Fashion          SeaShell  2015-08-04
# 492         492   24      ComputerAndMobile          DarkBlue  2015-01-21
# 493         493   30  ElectronicsAppliances    MediumSeaGreen  2015-03-06
# 494         494   32      ComputerAndMobile     DarkTurquoise  2015-06-04
# 495         495   32             Grossaries               Tan  2015-03-13
# 496         496   33      ComputerAndMobile     PaleVioletRed  2015-01-08
# 497         497   31             Grossaries          Cornsilk  2015-05-11
# 498         498   34      ComputerAndMobile              Teal  2015-05-30
# 499         499   37      ComputerAndMobile       DarkMagenta  2015-08-15
#
#      Discount Gender               Iteam Region      Time
# 0          55      M             MacBook  city3  22:55:49
# 1          25      F           Radowatch  city4  20:39:50
# 2          25      F       RaybanGlasses  city4  18:52:44
# 3          50      M                Dell  city3  21:13:25
# 4           5      M           WheelSoap  city5  07:09:52
# 5          25      F           Radowatch  city1  06:03:03
# 6          65      M            IphoneXs  city2  22:40:52
# 7           5      F         GaramMasala  city5  07:35:45
# 8          50      M             MacBook  city3  23:38:34
# 9          60      M           OnePlus6T  city3  17:49:49
# 10         55      M            IphoneXs  city3  18:26:54
# 11         50      M                Dell  city3  16:22:02
# 12         50      M             MacBook  city3  21:19:35
# 13         50      M           OnePlus6T  city3  19:17:07
# 14         25      F       RaybanGlasses  city1  02:50:30
# 15         25      F       Garniearcream  city1  01:06:17
# 16         30      F           NikeShoes  city1  03:52:08
# 17         10      F              Turdal  city5  00:31:27
# 18         30      F       RaybanGlasses  city1  00:48:38
# 19         15      F         GaramMasala  city5  05:48:45
# 20         50      M             MacBook  city2  15:35:44
# 21         60      M           OnePlus6T  city2  20:05:50
# 22         50      M            IphoneXs  city2  08:50:29
# 23         40      M       MorphyToaster  city5  11:47:29
# 24         15      F           WheelSoap  city5  01:51:15
# 25         55      M           OnePlus6T  city3  22:32:33
# 26         35      M         UshaIronBox  city5  12:53:51
# 27         40      M       MorphyToaster  city4  14:14:04
# 28         65      M             MacBook  city2  17:55:17
# 29         10      F              Turdal  city1  03:44:53
# ..        ...    ...                 ...    ...       ...
# 470        65      M            IphoneXs  city2  20:51:53
# 471        10      F         GaramMasala  city5  06:27:25
# 472         5      F           WheelSoap  city5  06:40:37
# 473        60      M           OnePlus6T  city3  17:40:47
# 474        60      M            IphoneXs  city3  20:53:33
# 475        60      M                Dell  city2  21:29:42
# 476        15      F           WheelSoap  city5  04:39:07
# 477         5      F              Turdal  city1  07:44:04
# 478        50      M            IphoneXs  city2  17:50:36
# 479        40      M       MorphyToaster  city5  14:40:08
# 480        60      M             MacBook  city3  08:28:24
# 481         5      F              Turdal  city5  01:47:02
# 482        65      M            IphoneXs  city3  21:42:24
# 483        10      F         GaramMasala  city5  05:11:20
# 484        35      M                LGTV  city5  12:13:21
# 485        40      M  SamsungRefigerator  city5  12:33:16
# 486        10      F             Ketchup  city5  07:50:46
# 487        10      F         GaramMasala  city5  06:42:03
# 488        10      F           WheelSoap  city1  01:02:39
# 489        15      F              Turdal  city5  03:38:56
# 490        65      M            IphoneXs  city2  16:59:52
# 491        30      F       Garniearcream  city1  02:10:05
# 492        60      M             MacBook  city2  22:37:33
# 493        35      M  SamsungRefigerator  city4  12:01:37
# 494        60      M            IphoneXs  city3  11:00:16
# 495         5      F         GaramMasala  city5  07:02:07
# 496        50      M             MacBook  city3  10:34:13
# 497        15      F              Turdal  city5  02:23:25
# 498        65      M            IphoneXs  city3  09:56:23
# 499        65      M                Dell  city3  10:17:29
#
# [500 rows x 10 columns]

# %%
dataset=np.array(dataset)
x=[]
for i in range(dataset.shape[0]):
    time=int(dataset[i][9][:2])*60+int(dataset[i][9][3:5])
    x.append([dataset[i][1],dataset[i][5],time,dataset[i][7]])
x=np.array(x,dtype=object)

# %%
x
# Out:
# array([[39, 55, 1375, 'MacBook'],
#        [53, 25, 1239, 'Radowatch'],
#        [53, 25, 1132, 'RaybanGlasses'],
#        ...,
#        [31, 15, 143, 'Turdal'],
#        [34, 65, 596, 'IphoneXs'],
#        [37, 65, 617, 'Dell']], dtype=object)

# %%
def distance(p1,p2):
    t1=p1[0]-p2[0]
    t2=p1[1]-p2[1]
    t3=p1[2]-p2[2]
    return ((t1*t1+t2*t2+t3*t3))

# %%
iteams=['LGTV','SamsungRefigerator','UshaIronBox','MorphyToaster','NikeShoes','Radowatch','RaybanGlasses','Garniearcream','MacBook','OnePlus6T','IphoneXs','Dell','WheelSoap','Turdal','Ketchup','GaramMasala']
iteams=np.array(iteams)
pname=['ElectronicsAppliances','Fashion','ComputerAndMobile','Grossaries']
pname=np.array(pname)

# %%
centroid=np.zeros((iteams.shape[0],3))
count=np.zeros((iteams.shape[0]))
for i in range(x.shape[0]):
    t=int(np.where(iteams==x[i][3])[0])
    centroid[t][0]=centroid[t][0]+x[i][0]
    centroid[t][1]=centroid[t][0]+x[i][1]
    centroid[t][2]=centroid[t][0]+x[i][2]
    count[t]=count[t]+1
   

for i in range(iteams.shape[0]):
    centroid[i]=centroid[i]/count[i]

# %%
centroid
# Out:
# array([[ 33.95      ,  35.7       ,  70.6       ],
#        [ 31.78571429,  34.28571429,  83.28571429],
#        [ 30.4       ,  33.9       , 118.4       ],
#        [ 31.9047619 ,  33.80952381,  73.80952381],
#        [ 29.6       ,  32.1       , 132.6       ],
#        [ 30.36842105,  31.68421053,  40.42105263],
#        [ 27.82352941,  29.58823529,  29.11764706],
#        [ 28.33333333,  30.        ,  35.55555556],
#        [ 33.55072464,  34.27536232,  42.73913043],
#        [ 32.27868852,  33.26229508,  49.6557377 ],
#        [ 31.70149254,  32.67164179,  40.59701493],
#        [ 33.46296296,  34.66666667,  44.88888889],
#        [ 36.30769231,  36.69230769,  38.69230769],
#        [ 33.90322581,  34.38709677,  38.51612903],
#        [ 36.09677419,  36.41935484,  51.25806452],
#        [ 34.8125    ,  34.96875   ,  48.        ]])

# %%
distancetable=np.zeros((iteams.shape[0],iteams.shape[0]))
for i in range(iteams.shape[0]):
    for j in range(iteams.shape[0]):
        distancetable[i][j]=distance(centroid[i],centroid[j])

# %%
distancetable=np.array(distancetable,dtype=int)
print distancetable
# Out:
# [[    0   167  2300    18  3875   939  1795  1292   778   447   914   662
#    1024  1031   379   512]
#  [  167     0  1235    90  2441  1846  2971  2308  1647  1132  1824  1477
#    2014  2008  1048  1254]
#  [ 2300  1235     0  1990   205  6085  7996  6882  5734  4729  6056  5413
#    6396  6393  4546  4976]
#  [   18    90  1990     0  3464  1121  2031  1490   968   583  1104   839
#    1260  1249   532   675]
#  [ 3875  2441   205  3464     0  8497 10718  9423  8095  6888  8469  7714
#    8884  8875  6677  7192]
#  [  939  1846  6085  1121  8497     0   138    30    22    91     2    38
#      63    23   172    87]
#  [ 1795  2971  7996  2031 10718   138     0    41   240   455   156   306
#     214   148   605   434]
#  [ 1292  2308  6882  1490  9423    30    41     0    97   225    43   135
#     118    59   348   221]
#  [  778  1647  5734   968  8095    22   240    97     0    50    10     4
#      29    17    83    29]
#  [  447  1132  4729   583  6888    91   455   225    50     0    82    26
#     148   127    27    12]
#  [  914  1824  6056  1104  8469     2   156    43    10    82     0    25
#      41    12   147    69]
#  [  662  1477  5413   839  7714    38   306   135     4    26    25     0
#      50    40    50    11]
#  [ 1024  2014  6396  1260  8884    63   214   118    29   148    41    50
#       0    11   158    91]
#  [ 1031  2008  6393  1249  8875    23   148    59    17   127    12    40
#      11     0   171    91]
#  [  379  1048  4546   532  6677   172   605   348    83    27   147    50
#     158   171     0    14]
#  [  512  1254  4976   675  7192    87   434   221    29    12    69    11
#      91    91    14     0]]

# %%
#predicting the associated products
for i in range(iteams.shape[0]):
    median=np.median(distancetable[i])/2
    print "If product "+str(iteams[i])+ "is choosen then other similar products which might be choosen are"
    string=""
    for j in range(iteams.shape[0]):
        if(distancetable[i][j]<=median):
            string=string+str(" ")+str(iteams[j])
    print (string+"\n")
# Out:
# If product LGTVis choosen then other similar products which might be choosen are
#  LGTV SamsungRefigerator MorphyToaster Ketchup
#
# If product SamsungRefigeratoris choosen then other similar products which might be choosen are
#  LGTV SamsungRefigerator MorphyToaster
#
# If product UshaIronBoxis choosen then other similar products which might be choosen are
#  LGTV SamsungRefigerator UshaIronBox MorphyToaster NikeShoes
#
# If product MorphyToasteris choosen then other similar products which might be choosen are
#  LGTV SamsungRefigerator MorphyToaster
#
# If product NikeShoesis choosen then other similar products which might be choosen are
#  SamsungRefigerator UshaIronBox MorphyToaster NikeShoes
#
# If product Radowatchis choosen then other similar products which might be choosen are
#  Radowatch Garniearcream MacBook IphoneXs Dell Turdal
#
# If product RaybanGlassesis choosen then other similar products which might be choosen are
#  Radowatch RaybanGlasses Garniearcream IphoneXs Turdal
#
# If product Garniearcreamis choosen then other similar products which might be choosen are
#  Radowatch RaybanGlasses Garniearcream IphoneXs Turdal
#
# If product MacBookis choosen then other similar products which might be choosen are
#  Radowatch MacBook IphoneXs Dell WheelSoap Turdal GaramMasala
#
# If product OnePlus6Tis choosen then other similar products which might be choosen are
#  MacBook OnePlus6T Dell Ketchup GaramMasala
#
# If product IphoneXsis choosen then other similar products which might be choosen are
#  Radowatch MacBook IphoneXs Dell Turdal
#
# If product Dellis choosen then other similar products which might be choosen are
#  MacBook IphoneXs Dell GaramMasala
#
# If product WheelSoapis choosen then other similar products which might be choosen are
#  Radowatch MacBook IphoneXs Dell WheelSoap Turdal
#
# If product Turdalis choosen then other similar products which might be choosen are
#  Radowatch MacBook IphoneXs Dell WheelSoap Turdal
#
# If product Ketchupis choosen then other similar products which might be choosen are
#  MacBook OnePlus6T Dell Ketchup GaramMasala
#
# If product GaramMasalais choosen then other similar products which might be choosen are
#  MacBook OnePlus6T Dell Ketchup GaramMasala

# %%
#if response id negative decrease the value by .15 time else increase the value by .15 times
