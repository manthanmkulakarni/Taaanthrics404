# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

# %%
data=pd.read_csv('/Users/manthanmkulakarni/Documents/Paytmmodel/crowddatasetforsihmodified.csv')

# %%
data
# Out:
#      Unnamed: 0  Age               Catagory             Color        Date  \
# 0             0   39      ComputerAndMobile            Violet  2015-02-24
# 1             1   53                Fashion         DarkGreen  2015-06-07
# 2             2   53                Fashion            Bisque  2015-01-01
# 3             3   41      ComputerAndMobile       SaddleBrown  2015-04-28
# 4             4   45             Grossaries  MediumAquaMarine  2015-07-21
# 5             5   18                Fashion       FloralWhite  2015-05-21
# 6             6   19      ComputerAndMobile     DarkSlateBlue  2015-08-01
# 7             7   34             Grossaries              Aqua  2015-04-06
# 8             8   43      ComputerAndMobile            Salmon  2015-04-21
# 9             9   31      ComputerAndMobile             Brown  2015-01-25
# 10           10   35      ComputerAndMobile            Tomato  2015-07-11
# 11           11   32      ComputerAndMobile            Tomato  2015-05-29
# ...

# %%
data=np.array(data)

# %%
x=data.T[1:3]
y=data.T[8]
x=x.reshape(500,2)
y=y.reshape(500,1)

# %%
clf=LogisticRegression()
clf.fit(x,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-cda954947ef1> in <module>()
#       1 clf=LogisticRegression()
# ----> 2 clf.fit(x,y)
#
# /usr/local/lib/python2.7/site-packages/sklearn/linear_model/logistic.pyc in fit(self, X, y, sample_weight)
#    1286
#    1287         X, y = check_X_y(X, y, accept_sparse='csr', dtype=_dtype, order="C",
# -> 1288                          accept_large_sparse=solver != 'liblinear')
#    1289         check_classification_targets(y)
#    1290         self.classes_ = np.unique(y)
#
# /usr/local/lib/python2.7/site-packages/sklearn/utils/validation.pyc in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     754                     ensure_min_features=ensure_min_features,
# ...

# %%
clf.score(x[25:45],y[25:45])
# Out:
# 0.4

# %%
clf2=SVC()
clf2.fit(x,y)
clf2.score(x[25:45],y[25:45])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-0455884262c7> in <module>()
#       1 clf2=SVC()
# ----> 2 clf2.fit(x,y)
#       3 clf2.score(x[25:45],y[25:45])
#
# /usr/local/lib/python2.7/site-packages/sklearn/svm/base.pyc in fit(self, X, y, sample_weight)
#     147         X, y = check_X_y(X, y, dtype=np.float64,
#     148                          order='C', accept_sparse='csr',
# --> 149                          accept_large_sparse=False)
#     150         y = self._validate_targets(y)
#     151
#
# /usr/local/lib/python2.7/site-packages/sklearn/utils/validation.pyc in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     754                     ensure_min_features=ensure_min_features,
# ...

# %%
x.shape
# Out:
# (2, 500)
