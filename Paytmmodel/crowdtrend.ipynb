# %%
import pandas as pd
import numpy as np
import random
import seaborn as sb

# %%
data=pd.read_csv("/Users/manthanmkulakarni/Downloads/fraud-ecommerce/Fraud_Data.csv")

# %%
data
# Out:
#         user_id          signup_time        purchase_time  purchase_value  \
# 0         22058  2015-02-24 22:55:49  2015-04-18 02:47:11              34
# 1        333320  2015-06-07 20:39:50  2015-06-08 01:38:54              16
# 2          1359  2015-01-01 18:52:44  2015-01-01 18:52:45              15
# 3        150084  2015-04-28 21:13:25  2015-05-04 13:54:50              44
# 4        221365  2015-07-21 07:09:52  2015-09-09 18:40:53              39
# 5        159135  2015-05-21 06:03:03  2015-07-09 08:05:14              42
# 6         50116  2015-08-01 22:40:52  2015-08-27 03:37:57              11
# 7        360585  2015-04-06 07:35:45  2015-05-25 17:21:14              27
# 8        159045  2015-04-21 23:38:34  2015-06-02 14:01:54              30
# 9        182338  2015-01-25 17:49:49  2015-03-23 23:05:42              62
# 10       199700  2015-07-11 18:26:54  2015-10-28 21:59:40              13
# 11        73884  2015-05-29 16:22:02  2015-06-16 05:45:58              58
# ...

# %%
date=np.array(data['signup_time'])
age=np.array(data['age'])

# %%
time=[]
pname=['SGalaxy','Garniear','KGF','MacBook','OnePlus6T']
product=[]
for i in range(date.shape[0]):
    time.append(date[i][11:])
    product.append(pname[random.randrange(1,25,3)%5])
    date[i]=date[i][0:10]

# %%
frame={'time':time,'date':date,'age':age,'product':product}

# %%
frame=pd.DataFrame(frame)

# %%
frame.to_csv('paytmcrowddata.csv')

# %%
data2=pd.read_csv('/Users/manthanmkulakarni/Downloads/paytmcrowddata.csv')
data2
# Out:
#         Unnamed: 0  age        date    product      time
# 0                0   39  2015-02-24    MacBook  22:55:49
# 1                1   53  2015-06-07   Garniear  20:39:50
# 2                2   53  2015-01-01  OnePlus6T  18:52:44
# 3                3   41  2015-04-28    MacBook  21:13:25
# 4                4   45  2015-07-21   Garniear  07:09:52
# 5                5   18  2015-05-21   Garniear  06:03:03
# 6                6   19  2015-08-01        KGF  22:40:52
# 7                7   34  2015-04-06  OnePlus6T  07:35:45
# 8                8   43  2015-04-21        KGF  23:38:34
# 9                9   31  2015-01-25        KGF  17:49:49
# 10              10   35  2015-07-11    SGalaxy  18:26:54
# 11              11   32  2015-05-29    MacBook  16:22:02
# 12              12   33  2015-06-16        KGF  21:19:35
# 13              13   38  2015-03-03  OnePlus6T  19:17:07
# 14              14   24  2015-02-16        KGF  02:50:30
# ...

# %%
time=[]
age=[]
for i in range(data2.size-1):
    time.append(int(data2['time'][i][0:2])*60+int(data2['time'][i][3:5]))
    age.append(data2['age'][i])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-65-a21971d61aa6> in <module>()
#       2 age=[]
#       3 for i in range(data2.size-1):
# ----> 4     time.append(int(data2['time'][i][0:2])*60+int(data2['time'][i][3:5]))
#       5     age.append(data2['age'][i])
#
# /usr/local/lib/python2.7/site-packages/pandas/core/series.pyc in __getitem__(self, key)
#     765         key = com._apply_if_callable(key, self)
#     766         try:
# --> 767             result = self.index.get_value(self, key)
#     768
#     769             if not is_scalar(result):
#
# /usr/local/lib/python2.7/site-packages/pandas/core/indexes/base.pyc in get_value(self, series, key)
#    3116         try:
#    3117             return self._engine.get_value(s, k,
# -> 3118                                           tz=getattr(series.dtype, 'tz', None))
#    3119         except KeyError as e1:
# ...

# %%
import matplotlib.pyplot as plt

# %%
cat1t=[]
cat1a=[]
cat2t=[]
cat2a=[]
cat3t=[]
cat4a=[]
cat4t=[]
cat3a=[]
cat5a=[]
cat5t=[]
for i in range(len(age)/10):
    if(data2['product'][i]==pname[0]):
        cat1a.append(age[i])
        cat1t.append(time[i])
    elif(data2['product'][i]==pname[1]):
        cat2a.append(age[i])
        cat2t.append(time[i])
    elif(data2['product'][i]==pname[2]):
        cat3a.append(age[i])
        cat3t.append(time[i])
    elif(data2['product'][i]==pname[3]):
        cat4a.append(age[i])
        cat4t.append(time[i])
    else:
        cat5t.append([age[i],time[i]])

# %%
cat1t[10]
# Out:
# 548

# %%
plt.scatter(cat1a[:100],cat1t[:100],color='red')
plt.scatter(cat2a[:100],cat2t[:100],color='blue')
plt.scatter(cat3a[:100],cat3t[:100],color='green')

plt.show()

# %%
def dist(x,y):
    return ((x[0]-x[1])*(x[0]-x[1])+(y[0]-y[1])*(y[0]-y[1]))

# %%
data2=np.array(data2)

# %%
for i in range(data2.shape[0]):
    data2[i][4]=int(data2[i][4][:2])*60+int(data2[i][4][3:5])

# %%
points=[]
for i in range(data2.shape[0]/5000):
    points.append(data2[random.randrange(0,data2.shape[0],100)])

# %%
points=np.array(points)

# %%
plt.scatter(points.T[1],points.T[4])
plt.show()

# %%
for i in range(1):
    distance=[]
    for j in range(1,data2.shape[0]):
        distance.append([7,8])
    distance=np.array(distance)    
    for j in range(distance.shape[0]):
        for k in range(distance.shape[0]-j-1):
            if(distance[k][1]>distance[k+1][1]):
                temp=distance[k]
                distance[k]=distance[k+1]
                distance[k+1]=temp
    distance
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-97-db0dfdbf6f25> in <module>()
#       6     for j in range(distance.shape[0]):
#       7         for k in range(distance.shape[0]-j-1):
# ----> 8             if(distance[k][1]>distance[k+1][1]):
#       9                 temp=distance[k]
#      10                 distance[k]=distance[k+1]
#
# KeyboardInterrupt:
